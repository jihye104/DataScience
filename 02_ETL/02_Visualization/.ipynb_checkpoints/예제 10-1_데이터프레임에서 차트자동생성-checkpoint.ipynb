# %% [markdown]
# ## 데이터 프레임에서 plot 그래프 생성

# %% [markdown]
# ### 현재 pandas 버전 기준 plot, hist, boxplot의 자동생성을 지원하고 있음

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# periods => 기간의 수를 지정

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2020', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.head()
# Out:
# 2020-01-01    1.170800
# 2020-01-02   -0.100947
# 2020-01-03   -0.652964
# 2020-01-04   -1.926476
# 2020-01-05   -2.138456
# Freq: D, dtype: float64

# %%
ts.plot()
plt.show()

# %%
ts.hist()
# Out:
# <AxesSubplot:>

# %%
ts.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 4), 
                  index=ts.index, 
                  columns=list(['홍길동','나투자','워렌버핏','이재용']))
df
# Out:
#                  홍길동       나투자      워렌버핏       이재용
# 2020-01-01  0.087127 -0.615131 -0.032798  1.771605
# 2020-01-02  1.128994  0.075446 -0.627722  0.183202
# 2020-01-03  1.581726 -0.430501  0.958703 -1.666515
# 2020-01-04  1.455575 -0.065784 -2.673756  0.470671
# 2020-01-05  0.703270  1.639852 -0.302813 -1.081941
# ...              ...       ...       ...       ...
# 2022-09-22  0.074932 -0.043540  0.261553  0.485199
# 2022-09-23 -0.551040 -0.324183  0.710697 -0.675305
# 2022-09-24 -1.086014 -1.249507  0.617588 -0.604371
# 2022-09-25 -1.455130  0.233394 -0.763024  0.034276
# 2022-09-26 -1.706754  0.491602  0.697875  0.212291
#
# [1000 rows x 4 columns]

# %%
df = df.cumsum()/100

# %%
df.plot(title="2020년 이후 투자전문가별 수익률")
plt.show()

# %%
df.hist(bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'홍길동'}>,
#         <AxesSubplot:title={'center':'나투자'}>],
#        [<AxesSubplot:title={'center':'워렌버핏'}>,
#         <AxesSubplot:title={'center':'이재용'}>]], dtype=object)

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sample = titanic[['age']]
sample.head()
# Out:
#     age
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
sample.boxplot()
# Out:
# <AxesSubplot:>

# %%
sample = titanic[['age','fare']]
sample.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
sample.boxplot()
# Out:
# <AxesSubplot:>

# %%
sample.boxplot(notch=True)
# Out:
# <AxesSubplot:>
