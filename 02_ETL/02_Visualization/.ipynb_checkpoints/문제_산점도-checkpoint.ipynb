# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
import seaborn as sns
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
planets.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
plt.scatter(x = planets['orbital_period'], y = planets['distance'])
plt.xlabel('궤도주기')
plt.ylabel('거리')
plt.title('행성 궤도주기/거리 별 분포도')
plt.show()

# %%
plt.scatter(x = planets['year'], y = planets['mass'])
plt.xlabel('년도')
plt.ylabel('덩어리')
plt.title('행성 년도/덩어리 별 분포도')
plt.show()

# %%
np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n))**2

FIRST = 0
LAST = n-1
MEDIAN = int(n/2)
X_PADDING = 0.17
Y_PADDING = 0.07

plt.scatter(x, y, s=area, c='yellow')
plt.scatter(x[FIRST], y[FIRST], s=area[FIRST], c='red')
plt.text(x[FIRST]-X_PADDING, y[FIRST]+Y_PADDING, '최초 관측된 데이터',
         fontdict={'size': 14})

plt.scatter(x[MEDIAN], y[MEDIAN], s=area[MEDIAN], c='green')
plt.text(x[MEDIAN]-X_PADDING+0.15, y[MEDIAN]+Y_PADDING, '1/2 지점 발견한 데이터',
        fontdict={'size': 14})

plt.scatter(x[LAST], y[LAST], s=area[LAST], c='blue')
plt.text(x[LAST]-X_PADDING-0.1, y[LAST]+Y_PADDING+0.05, '마지막 관측된 데이터',
        fontdict={'size': 14})

plt.show()
