# %% [markdown]
# ## 축 위치 조절하기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# np.linspace(-3, 3, 3) => -3 ~ 3 사이를 숫자 3개로 채워준다

# %%
plt.style.use('default')

plt.rcParams['figure.figsize'] = (6, 3)
plt.rcParams['font.size'] = 12

fig, ax = plt.subplots()

ax.set_title('Mean Squared Error', pad=20)

ax.set_xlim(-3, 3)
ax.set_ylim(0, 3)

ax.set_xticks([-3, -2, -1, 0, 1, 2, 3])
ax.set_yticks([1, 2, 3])

x = np.linspace(-3, 3, 100)

ax.set_xlabel('y_true - y_pred', fontdict={'fontsize': 14}, labelpad=10)

ax.plot(x, x**2, color='#4799FF', linewidth=5)

plt.show()

# %% [markdown]
# ax.spines['left'].set_position('center') => 그래프의 왼쪽 축을 가운데로 위치이동

# %%
plt.style.use('default')

plt.rcParams['figure.figsize'] = (6, 3)
plt.rcParams['font.size'] = 12

fig, ax = plt.subplots()

ax.set_title('Mean Squared Error', pad=20)

ax.set_xlim(-3, 3)
ax.set_ylim(0, 3)

ax.set_xticks([-3, -2, -1, 0, 1, 2, 3])
ax.set_yticks([1, 2, 3])

x = np.linspace(-3, 3, 100)

ax.set_xlabel('y_true - y_pred', fontdict={'fontsize': 14}, labelpad=10)

ax.plot(x, x**2, color='#4799FF', linewidth=5)

ax.spines['left'].set_position('center')

plt.show()

# %% [markdown]
# ax.spines['right'].set_visible(False) => 그래프의 오른쪽 축을 보이지 않게
# set_visible(True) 가 디폴트

# %%
plt.style.use('default')

plt.rcParams['figure.figsize'] = (6, 3)
plt.rcParams['font.size'] = 12

fig, ax = plt.subplots()

ax.set_title('Mean Squared Error', pad=20)

ax.set_xlim(-3, 3)
ax.set_ylim(0, 3)

ax.set_xticks([-3, -2, -1, 0, 1, 2, 3])
ax.set_yticks([1, 2, 3])

x = np.linspace(-3, 3, 100)

ax.set_xlabel('y_true - y_pred', fontdict={'fontsize': 14}, labelpad=10)

ax.plot(x, x**2, color='#4799FF', linewidth=5)

ax.spines['left'].set_position('center')
ax.spines['right'].set_visible(False)

plt.show()

# %%
plt.style.use('default')

plt.rcParams['figure.figsize'] = (6, 3)
plt.rcParams['font.size'] = 12

fig, ax = plt.subplots()

ax.set_title('Mean Squared Error', pad=20)

ax.set_xlim(-3, 3)
ax.set_ylim(0, 3)

ax.set_xticks([-3, -2, -1, 0, 1, 2, 3])
ax.set_yticks([1, 2, 3])

x = np.linspace(-3, 3, 100)

ax.set_xlabel('y_true - y_pred', fontdict={'fontsize': 14}, labelpad=10)

ax.plot(x, x**2, color='#4799FF', linewidth=5)

ax.spines['left'].set_position('center')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.show()

# %% [markdown]
# ax.tick_params('both',length = 0) => xtick, ytick 둘 다 tick 의 눈금 길이를 0으로

# %%
plt.style.use('default')

plt.rcParams['figure.figsize'] = (6, 3)
plt.rcParams['font.size'] = 12

fig, ax = plt.subplots()

ax.set_title('Mean Squared Error', pad=20)

ax.set_xlim(-3, 3)
ax.set_ylim(0, 3)

ax.set_xticks([-3, -2, -1, 0, 1, 2, 3])
ax.set_yticks([1, 2, 3])

x = np.linspace(-3, 3, 100)

ax.set_xlabel('y_true - y_pred', fontdict={'fontsize': 14}, labelpad=10)

ax.plot(x, x**2, color='#4799FF', linewidth=5)

ax.spines['left'].set_position('center')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.tick_params('both',length = 0)

plt.show()

# %% [markdown]
# ## 이중 Y축 표시하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 기본사용

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# twinx() => x 축만 공유

# %%
plt.style.use('default')

plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.arange(0, 3)
y1 = x + 1
y2 = [3,2,1]

fig, ax1 = plt.subplots()
ax1.plot(x,y1, color = 'green')

ax2 = ax1.twinx()
ax2.plot(x,y2, color = 'deeppink')

plt.show()

# %%
plt.style.use('default')

plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.arange(0, 3)
y1 = x + 1
y2 = [6,3,2]

fig, ax1 = plt.subplots()
ax1.plot(x,y1, color = 'green')

ax2 = ax1.twinx()
ax2.plot(x,y2, color = 'deeppink')

plt.show()

# %% [markdown]
# ### 축 레이블 표시하기

# %%
plt.style.use('default')

plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.arange(0, 3)
y1 = x + 1
y2 = [6,3,2]

fig, ax1 = plt.subplots()

ax1.set_xlabel('X-Axis')
ax1.set_ylabel('1st Y-Axis')
ax1.plot(x,y1, color = 'green')

ax2 = ax1.twinx()

ax2.set_ylabel('2nd Y-Axis')
ax2.plot(x,y2, color = 'deeppink')

plt.show()

# %% [markdown]
# ### 범례 표시하기 1

# %%
plt.style.use('default')

plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.arange(0, 3)
y1 = x + 1
y2 = [6,3,2]

fig, ax1 = plt.subplots()

ax1.set_xlabel('X-Axis')
ax1.set_ylabel('1st Y-Axis')
ax1.plot(x,y1, color = 'green', label='1st Data')
ax1.legend(loc='upper right')

ax2 = ax1.twinx()

ax2.set_ylabel('2nd Y-Axis')
ax2.plot(x,y2, color = 'deeppink', label='2nd Data')
ax2.legend(loc='lower right')

plt.show()

# %% [markdown]
# ### 범례 표시하기 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.style.use('default')

plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.arange(0, 3)
y1 = x + 1
y2 = [6,3,2]

fig, ax1 = plt.subplots()

ax1.set_xlabel('X-Axis')
ax1.set_ylabel('1st Y-Axis')
line1 = ax1.plot(x,y1, color = 'green', label='1st Data')

ax2 = ax1.twinx()

ax2.set_ylabel('2nd Y-Axis')
line2 = ax2.plot(x,y2, color = 'deeppink', label='2nd Data')

lines = line1+line2
labels = [l.get_label() for l in lines]

ax1.legend(lines,labels, loc = 'upper right')

plt.show()
